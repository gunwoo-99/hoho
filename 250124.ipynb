# %%
# !pip install seaborn
# !pip install matplotlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached matplotlib-3.10.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.1-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.10.0-cp313-cp313-win_amd64.whl (8.0 MB)
# Using cached contourpy-1.3.1-cp313-cp313-win_amd64.whl (220 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------ --------------------- 1.0/2.2 MB 20.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 7.2 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# ...

# %%
#141
리스트 = [100, 200, 300]

for i in 리스트:
    print(i + 10 )
# Out:
# 110
# 210
# 310

# %%
#142
리스트 = ['김밥', '라면', '튀김']

for i in 리스트:
    print("오늘의 메뉴:", i)
# Out:
# 오늘의 메뉴: 김밥
# 오늘의 메뉴: 라면
# 오늘의 메뉴: 튀김

# %%
#143
리스트 = ["SK하이닉스", "삼성전자", "LG전자"]

for i in 리스트:
    print(len(i))
# Out:
# 6
# 4
# 4

# %%
#144
리스트 = ["dog", "cat", "parrot"]

for i in 리스트:
    print(i, len(i))
# Out:
# dog 3
# cat 3
# parrot 6

# %%
#145
리스트 = ["dog", "cat", "parrot"]

for i in 리스트:
    print(i[0])
# Out:
# d
# c
# p

# %%
#147
리스트 = [1, 2, 3]

for i in 리스트:
    print("3 x", i, "=", 3*i)
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9

# %%
#148
리스트 = ['가', '나', '다', '라']

for i in 리스트[1:]:
    print(i)
# Out:
# 나
# 다
# 라

# %%
#149
list = ['가', '나', '다', '라']

for i in list[::2]:
    print(i)
# Out:
# 가
# 다

# %%
#150
list = ["가", "나", "다", "라"]

for i in list[::-1]:
    print(i)
# Out:
# 라
# 다
# 나
# 가

# %%
#151
list = [3, -20, -3, 44]

for i in list:
    if i < 0:
        print(i)
# Out:
# -20
# -3

# %%
#152
list = [3, 100, 23, 44]

for i in list:
    if i % 3 == 0:
        print(i)
# Out:
# 3

# %%
#153
list = [13, 21, 12, 14, 30, 18]

for i in list:
    if i < 20:
        if i % 3 == 0:
            print(i)

#153.1
list = [13, 21, 12, 14, 30, 18]

for i in list:
    if i < 20 and i % 3 == 0:
        print(i)

#이 두 코드 결과는 같은데, 코드 간에 차이가 있다고 볼 수 있을까?
#코딩에 대한 이해가 부족한 사람이 보기에는 153은 병렬로 작동하는 것이고, 153.1은 순차적으로 작동하는거임.
# Out:
# 12
# 18

# %%
# 153과 153.1에 대한 회고 (김민규)
# 우선, 153과 153.1은 똑같은 방식으로 작동함.
# 실행시간 면에서 약간의 차이가 존재할 수도 있겠다고 생각함. 
# 일반적으로 중첩구문(153)이 한줄구문(153.1)보다 약간 더 시간이 걸림.
# 그리고, 변수명을 list라고 작성하는 것은 지양해야 함.
# list는 리스트임을 명시하는 예약어이기 때문에 오류가 발생할 확률이 비약적으로 상승.
# 아래 코드를 통해 두 방식의 평균 실행시간 차이를 계산할 수 있음.
# 결론적으로, 두 방식의 실행시간 차이는 매우매우 작음. 

import time

def first(lst):
    for i in lst:
        if i < 20:
            if i % 3 == 0:
                print(i)

def second(lst):
    for i in lst:
        if i < 20 and i % 3 == 0:
            print(i)


lst = range(1, 100)

def measure_time(func, repeat=10000):
    start = time.time()
    for _ in range(repeat):
        func(lst)
    end = time.time()
    return (end - start) / repeat

n = 10000
avg_time_1 = measure_time(first, n)
avg_time_2 = measure_time(second, n)

print(f"first 평균 실행 시간: {avg_time_1}")
print(f"second 평균 실행 시간: {avg_time_2}")
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# ...
